# %%
from search import RAGSearch
from dotenv import load_dotenv
import os
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from search import RAGSearch
#       2 from dotenv import load_dotenv
#       3 import os
#
# File c:\Users\hp\Desktop\Sarkari-Dost\src\pipeline\search.py:3
#       1 import os
#       2 from dotenv import load_dotenv
# ----> 3 from .vectorstore import FaissVectorStore
#       4 from langchain_groq import ChatGroq
#       6 load_dotenv()
#
# ImportError: attempted relative import with no known parent package

# %%
load_dotenv()
rag_search = RAGSearch()
# Out:
# [INFO] Loaded embedding model: all-MiniLM-L6-v2
# [INFO] Loaded Faiss index and metadata from C:\Users\hp\Desktop\Sarkari-Dost\faiss_store
# [INFO] Groq LLM initialized: openai/gpt-oss-120b

# %%
query = "I want to apply for government schemes for farmers in India. Can you help me with the details?"

# %%
summary = rag_search.search_and_summarize(query)
print(summary)
# Out:
# [INFO] Querying vector store for: 'I want to apply for government schemes for farmers in India. Can you help me with the details?'
# **भारत में किसान‑के‑लिए मुख्य सरकारी योजनाएँ – आसान हिंदी में सारांश**
#
# | योजना | क्या मिलता है (लाभ) | कौन‑कौन योग्य है (Eligibility) | जरूरी काग़ज़ (Documents) | कैसे अप्लाई करें (Application) | आख़िरी तारीख |
# |------|-------------------|-------------------------------|------------------------|-------------------------------|--------------|
# | **प्रधाण मंत्री फसल बीमा योजना (PMFBY)** | फसल नुकसान (बाढ़, सूखा, कीट‑कीटाणु) पर बीमा रक़म सीधे बैंक में | • भारत का किसान <br>• असली खेती‑करता <br>• अपने खेत‑की‑जगह का रिकॉर्ड | • आधार कार्ड <br>• जमीन/लीज़ का काग़ज़ <br>• बैंक खाता विवरण | 1️⃣ नजदीकी बैंक या कृषि कार्यालय में फॉर्म भरें <br>2️⃣ या ऑनलाइन <br>   (PMFBY पोर्टल/बीमा कंपनी की साइट) <br>3️⃣ काग़ज़ जमा करें, प्रीमियम (ख़रीफ़ 1.5 % / रबी 2 %) भरें | कोई तय सीमा नहीं – हर साल खुली रहती है |
# | **प्रधानमंत्री किसान सम्मान निधि (PM‑KISAN)** | साल में ₹6,000 (तीन क़िस्तों में ₹2,000) सीधे बैंक में | • खेती वाले परिवार (पति‑पत्नी‑बच्चे) <br>• राज्य के ज़मीन‑रिकॉर्ड में खेती‑योग्य जमीन | • आधार कार्ड <br>• जमीन का काग़ज़ <br>• बैंक खाता <br>• फोटो‑आईडी, मोबाइल नंबर | 1️⃣ ऑनलाइन: **pmkisan.gov.in** पर आधार डालें, फॉर्म भरें <br>2️⃣ ऑफलाइन: नजदीकी CSC/कृषि कार्यालय में फॉर्म जमा करें | हर वित्तीय वर्ष (अक्टूबर‑सितंबर) में खुली रहती है |
# | **पोस्ट‑हार्वेस्ट मार्केटिंग स्कीम (मेघालय)** | किसान समूह/एसएचजी को ट्रक/मिनी‑ट्रक (₹2,00,000) 50 % सब्सिडी पर | • मेघालय का स्थायी निवासी किसान <br>• 0.2 हेक्टेयर या उससे ज़्यादा जमीन वाला | • आधार (आवश्यक नहीं, पर मदद के लिये) | 1️⃣ लिखित आवेदन (सादा काग़ज़) बनायें <br>2️⃣ ज़रूरी दस्तावेज़ (आधार आदि) की कॉपी लगायें <br>3️⃣ नजदीकी नारी अदालत/पंचायती कार्यालय में जमा करें | अभी चल रही है – समय‑सीमा नहीं दी गयी |
# | **बकरी‑पालन सब्सिडी (हिमाचल प्रदेश)** | 60 % सब्सिडी पर बकरी के झुंड (10‑5‑3 बकरियाँ) दिया जाता है | • हिमाचल के किसान (सभी वर्ग) <br>• बकरी‑पालन का प्रशिक्षण लेना अनिवार्य | • आधार, जमीन‑दस्तावेज़, बैंक खाता, फोटो‑आईडी, क़िसान‑आईडी (यदि हो) | 1️⃣ नजदीकी कृषि कार्यालय/बैंक में फॉर्म ले कर भरें <br>2️⃣ ऑनलाइन: राज्य कृषि पोर्टल (यदि उपलब्ध) | योजना अभी चल रही है – कोई विशेष डेडलाइन नहीं |
# | **मिहनतगार (MGNREGA) – ग्रामीण रोजगार** | साल में 100 दिन तक मजदूरी (₹/दिन) | • भारत का ग्रामीण निवासी, 18 साल से ऊपर | • आधार, नौकरी‑कार्ड (MGNREGA), बैंक/पोस्टल खाता, पता प्रमाण | 1️⃣ गाँव के पंचायत में लिखित/मौखिक आवेदन <br>2️⃣ या ऑनलाइन पोर्टल **www.nrega.nic.in** पर | हर साल खुली रहती है; काम मिलने पर तुरंत शुरू |
# | **प्रधानमंत्री ग्रामीण सड़क योजना (PMGSY)** | गाँव‑गाँव को अच्छी सड़कें (आवागमन आसान) | • गाँव/बस्ती जिसे अभी तक सड़क नहीं मिली | (नागरिक को कोई दस्तावेज़ नहीं चाहिए) | नागरिक सीधे आवेदन नहीं करते – राज्य‑सरकार चुनती है | चल रही योजना – समय‑सीमा नहीं दी गयी |
#
# ### कैसे शुरू करें?
# 1. **आधार कार्ड तैयार रखें** – अधिकांश योजनाओं में यह अनिवार्य है।
# 2. **जमीनी काग़ज़ (जमीन‑का‑काग़ज़, किराया‑नामा) इकट्ठा करें** – अगर आपके पास है तो आसान रहेगा।
# 3. **नजदीकी सरकारी कार्यालय/पंचायती कार्यालय/CSC (कॉमन सर्विस सेंटर) में जाएँ** – वहां मददगार अधिकारी आपको फॉर्म दिखा‑देगे।
# 4. **ऑनलाइन** – यदि आपके पास स्मार्टफ़ोन या कंप्यूटर है, तो ऊपर बताए गए आधिकारिक पोर्टल (pmkisan.gov.in, nrega.nic.in, pmfbY.gov.in आदि) पर जाकर “नया पंजीकरण” चुनें, अपना आधार नंबर डालें, बाकी जानकारी भरें और सबमिट करें।
# 5. **जमा करने के बाद** – अधिकारी आपके दस्तावेज़ जांचेंगे, मंज़ूरी देंगे और रक़म/सहायता सीधे आपके बैंक खाते में ट्रांसफ़र होगी।
#
# ### याद रखें
# - **सभी लाभ सीधे आपके बैंक खाते में** (DBT) जाते हैं, इसलिए बैंक खाता ज़रूरी है।
# - **दस्तावेज़ों की कॉपी बनाकर रख लें** – कभी‑कभी दोबारा माँगे जा सकते हैं।
# - **समय‑सीमा अक्सर नहीं होती**, पर कुछ योजनाओं में “पहले‑पहले को” आधार पर चयन होता है, इसलिए जल्दी अप्लाई करना फायदेमंद है।
#
# **अगर कोई बात समझ नहीं आई, तो नजदीकी गाँव/पंचायती कार्यालय में जा कर “किसान योजना मदद” के लिए पूछें – वे आपके लिये सब कुछ सरल भाषा में समझा देंगे।**
